# %% [markdown]
# install the Required Libraries

# %%
# !pip install timm==0.6.12 numpy==2.0.0 Pillow==9.2.0 PyYAML==6.0 setuptools==59.8.0 spikingjelly==0.0.0.0.12 torch torchvision torchaudio einops==0.7.0 huggingface-hub==0.24.6 opencv-python==4.8.1.78 wandb==0.16.0
# Out:
# ^C
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [21 lines of output]
#   + C:\Users\SiddheshPU\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe C:\Users\SiddheshPU\AppData\Local\Temp\pip-install-2vor5wfe\numpy_757f6ea94eeb4b9da2a996892873e7e1\vendored-meson\meson\meson.py setup C:\Users\SiddheshPU\AppData\Local\Temp\pip-install-2vor5wfe\numpy_757f6ea94eeb4b9da2a996892873e7e1 C:\Users\SiddheshPU\AppData\Local\Temp\pip-install-2vor5wfe\numpy_757f6ea94eeb4b9da2a996892873e7e1\.mesonpy-eydyidbp -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\SiddheshPU\AppData\Local\Temp\pip-install-2vor5wfe\numpy_757f6ea94eeb4b9da2a996892873e7e1\.mesonpy-eydyidbp\meson-python-native-file.ini
#   The Meson build system
#   Version: 1.2.99
# ...
